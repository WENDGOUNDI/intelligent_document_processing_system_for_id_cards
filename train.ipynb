# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move to the project folder
# %cd /content/drive/MyDrive/perso/yolov9_driver_license
# !ls
# Out:
# /content/drive/MyDrive/perso/yolov9_driver_license
# runs  split_data  Untitled0.ipynb  yolov8n.pt  yolov9c.pt

# %%
from ultralytics import YOLO

# Build a YOLOv9c model from pretrained weight
model = YOLO('yolov9c.pt')

# Display model information (optional)
model.info()

# Train the model
results = model.train(data='/content/drive/MyDrive/perso/yolov9_driver_license/split_data/data.yaml', epochs=100, imgsz=640)
# Out:
# YOLOv9c summary: 618 layers, 25590912 parameters, 0 gradients, 104.0 GFLOPs
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load the trained model
trained_model = YOLO('/content/drive/MyDrive/perso/yolov9_driver_license/runs/detect/train3/weights/best.pt')
# Run inference
results = trained_model('/content/drive/MyDrive/perso/yolov9_driver_license/split_data/test/images/midv2020-alb-id_18_jpg.rf.7e639a73a51ad0e47659ee6afd8a81f3.jpg')

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.show()  # display to screen
    result.save(filename='/content/drive/MyDrive/perso/yolov9_driver_license/split_data/result.jpg')  # save to disk
# Out:
# image 1/1 /content/drive/MyDrive/perso/yolov9_driver_license/split_data/test/images/midv2020-alb-id_18_jpg.rf.7e639a73a51ad0e47659ee6afd8a81f3.jpg: 416x640 1 birth_date, 1 birth_place, 1 document_number, 1 expiry_date, 1 face_photo, 1 gender, 1 issue_authority, 1 issue_date, 1 name, 1 nationality, 1 personal_number, 1 signature, 1 surname, 38.6ms
# Speed: 3.4ms preprocess, 38.6ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)

# %%
from glob import glob
count = 1
for i in glob("/content/drive/MyDrive/perso/yolov9_driver_license/split_data/test/images/*"):
  results = trained_model(i)

  # Process results list
  for result in results:
      boxes = result.boxes  # Boxes object for bounding box outputs
      masks = result.masks  # Masks object for segmentation masks outputs
      keypoints = result.keypoints  # Keypoints object for pose outputs
      probs = result.probs  # Probs object for classification outputs
      result.show()  # display to screen
      result.save(filename=f'/content/drive/MyDrive/perso/yolov9_driver_license/predicted_images/result_{count}.png')  # save to disk
      count +=1
# Out:
# image 1/1 /content/drive/MyDrive/perso/yolov9_driver_license/split_data/test/images/midv2020-alb-id_18_jpg.rf.7e639a73a51ad0e47659ee6afd8a81f3.jpg: 416x640 1 birth_date, 1 birth_place, 1 document_number, 1 expiry_date, 1 face_photo, 1 gender, 1 issue_authority, 1 issue_date, 1 name, 1 nationality, 1 personal_number, 1 signature, 1 surname, 38.0ms
# Speed: 3.6ms preprocess, 38.0ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/perso/yolov9_driver_license/split_data/test/images/midv2020-alb-id_66_jpg.rf.59a95e4355acd83cb8fa0495e97f70ac.jpg: 416x640 1 birth_date, 1 birth_place, 1 document_number, 1 expiry_date, 1 face_photo, 1 gender, 1 issue_authority, 1 issue_date, 1 name, 1 nationality, 1 personal_number, 1 signature, 1 surname, 37.6ms
# Speed: 2.5ms preprocess, 37.6ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# ...
